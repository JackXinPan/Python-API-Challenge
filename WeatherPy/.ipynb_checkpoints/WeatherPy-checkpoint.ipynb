# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
import requests
import numpy as np
import time
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st
import json
from api_keys import weather_api_key
# look for the closest city using geo coordinates
from citipy import citipy

# %% [markdown]
# ## Generate Cities List

# %%
#creating lists for for loop
cities = []
loops = ['']*1600

#loop to find cities 
for loop in loops:
    #create random set of geo coordinates
    lat = np.random.randint(-90,90)
    lng = np.random.randint(-180,180)
    #citipy to find nearest city to random set of geo coordinates
    city = citipy.nearest_city(lat, lng).city_name
    #prevent duplicate cities on list when appending
    if city not in cities:
        cities.append(city)

#number of cities to validate city list
len(cities)
# Out:
# 664

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Build partial query URL
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"
key = weather_api_key
query_url = f"{url}appid={key}&units={units}&q="

# %%
#lists for data weather data retrieval
city_name = []
lat = []
lng = []
max_temp = []
humidity = []
cloudiness = []
wind_speed = []
country = []
date = []
# setting indexing counters for for loop
record = 0
set_page = 1

#using print and for loop to create output of lists of weather stats for each valid city
print("Beginning Data Retrieval ")
print("-------------------------------")
for city in cities:
    #in case of Index or Type error if city has missing data
    try:
        response = requests.get(query_url + city).json()
        city_name.append(response['name'])
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        max_temp.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        cloudiness.append(response['clouds']['all'])
        wind_speed.append(response['wind']['speed'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        #for indexing responses
        if record > 49:
            record = 1
            set_page = set_page + 1
        else:
            record = record + 1
            
        print(f'Processing record {record} of Set {set_page} | {city}')
    #exception that occurs if city has missing data
    except(KeyError, IndexError):
              print("City not found. Skipping...")
print("-------------------------------")
print("Data Retrieval Complete")
print("-------------------------------")
# Out:
# Beginning Data Retrieval
# -------------------------------
# Processing record 1 of Set 1 | rikitea
# Processing record 2 of Set 1 | yellowknife
# Processing record 3 of Set 1 | aykhal
# City not found. Skipping...
# Processing record 4 of Set 1 | mulchen
# Processing record 5 of Set 1 | winston
# Processing record 6 of Set 1 | kapaa
# Processing record 7 of Set 1 | kyzyl-suu
# Processing record 8 of Set 1 | dano
# City not found. Skipping...
# Processing record 9 of Set 1 | albany
# Processing record 10 of Set 1 | leh
# Processing record 11 of Set 1 | abu dhabi
# Processing record 12 of Set 1 | norman wells
# Processing record 13 of Set 1 | dikson
# Processing record 14 of Set 1 | pierre
# Processing record 15 of Set 1 | cape town
# Processing record 16 of Set 1 | geraldton
# Processing record 17 of Set 1 | punta arenas
# Processing record 18 of Set 1 | kaitangata
# Processing record 19 of Set 1 | belmonte
# Processing record 20 of Set 1 | laguna
# Processing record 21 of Set 1 | vaini
# Processing record 22 of Set 1 | tepalcatepec
# Processing record 23 of Set 1 | heze
# Processing record 24 of Set 1 | lompoc
# City not found. Skipping...
# Processing record 25 of Set 1 | mishkino
# Processing record 26 of Set 1 | the pas
# Processing record 27 of Set 1 | vizinga
# Processing record 28 of Set 1 | neuquen
# Processing record 29 of Set 1 | nha trang
# Processing record 30 of Set 1 | adrar
# Processing record 31 of Set 1 | kahului
# Processing record 32 of Set 1 | hobart
# Processing record 33 of Set 1 | plouzane
# Processing record 34 of Set 1 | jamestown
# Processing record 35 of Set 1 | miandrivazo
# Processing record 36 of Set 1 | cambrai
# Processing record 37 of Set 1 | ushuaia
# Processing record 38 of Set 1 | capinota
# Processing record 39 of Set 1 | sao filipe
# Processing record 40 of Set 1 | faya
# Processing record 41 of Set 1 | rio gallegos
# Processing record 42 of Set 1 | chuy
# Processing record 43 of Set 1 | coruripe
# Processing record 44 of Set 1 | isangel
# Processing record 45 of Set 1 | rio grande
# City not found. Skipping...
# Processing record 46 of Set 1 | busselton
# Processing record 47 of Set 1 | fortuna
# Processing record 48 of Set 1 | lagoa
# Processing record 49 of Set 1 | bethel
# Processing record 50 of Set 1 | virden
# Processing record 1 of Set 2 | abu samrah
# Processing record 2 of Set 2 | antofagasta
# Processing record 3 of Set 2 | pevek
# Processing record 4 of Set 2 | hermanus
# Processing record 5 of Set 2 | aklavik
# Processing record 6 of Set 2 | puerto ayora
# Processing record 7 of Set 2 | mar del plata
# Processing record 8 of Set 2 | sioux lookout
# Processing record 9 of Set 2 | mataura
# Processing record 10 of Set 2 | vardo
# Processing record 11 of Set 2 | socorro
# Processing record 12 of Set 2 | kavieng
# Processing record 13 of Set 2 | ponta do sol
# City not found. Skipping...
# Processing record 14 of Set 2 | haverfordwest
# Processing record 15 of Set 2 | charlottetown
# Processing record 16 of Set 2 | jutai
# City not found. Skipping...
# Processing record 17 of Set 2 | bredasdorp
# Processing record 18 of Set 2 | castro
# Processing record 19 of Set 2 | qaanaaq
# Processing record 20 of Set 2 | cidreira
# Processing record 21 of Set 2 | smolenka
# Processing record 22 of Set 2 | butaritari
# Processing record 23 of Set 2 | hilo
# Processing record 24 of Set 2 | kamyzyak
# Processing record 25 of Set 2 | turan
# Processing record 26 of Set 2 | bage
# Processing record 27 of Set 2 | itarema
# Processing record 28 of Set 2 | thompson
# Processing record 29 of Set 2 | sitka
# Processing record 30 of Set 2 | hashtrud
# City not found. Skipping...
# City not found. Skipping...
# Processing record 31 of Set 2 | norden
# Processing record 32 of Set 2 | lavrentiya
# City not found. Skipping...
# Processing record 33 of Set 2 | ouallam
# Processing record 34 of Set 2 | sri aman
# Processing record 35 of Set 2 | kununurra
# Processing record 36 of Set 2 | atuona
# Processing record 37 of Set 2 | severo-kurilsk
# Processing record 38 of Set 2 | chokurdakh
# Processing record 39 of Set 2 | darovskoy
# Processing record 40 of Set 2 | cabras
# Processing record 41 of Set 2 | saint george
# City not found. Skipping...
# Processing record 42 of Set 2 | coquimbo
# Processing record 43 of Set 2 | pontal do parana
# Processing record 44 of Set 2 | iqaluit
# Processing record 45 of Set 2 | fort smith
# Processing record 46 of Set 2 | kihei
# Processing record 47 of Set 2 | mehamn
# Processing record 48 of Set 2 | alta floresta
# Processing record 49 of Set 2 | victoria
# Processing record 50 of Set 2 | mantua
# City not found. Skipping...
# City not found. Skipping...
# Processing record 1 of Set 3 | recodo
# Processing record 2 of Set 3 | bialogard
# Processing record 3 of Set 3 | nanortalik
# Processing record 4 of Set 3 | longyearbyen
# Processing record 5 of Set 3 | new smyrna beach
# Processing record 6 of Set 3 | bahia blanca
# Processing record 7 of Set 3 | ziro
# Processing record 8 of Set 3 | lebu
# Processing record 9 of Set 3 | wanning
# Processing record 10 of Set 3 | hobyo
# Processing record 11 of Set 3 | georgetown
# Processing record 12 of Set 3 | lorengau
# Processing record 13 of Set 3 | east london
# Processing record 14 of Set 3 | nikolskoye
# Processing record 15 of Set 3 | kodiak
# Processing record 16 of Set 3 | la rosa
# Processing record 17 of Set 3 | guerrero negro
# Processing record 18 of Set 3 | luderitz
# Processing record 19 of Set 3 | sagua la grande
# Processing record 20 of Set 3 | saint-philippe
# Processing record 21 of Set 3 | bhadasar
# Processing record 22 of Set 3 | barela
# Processing record 23 of Set 3 | girona
# Processing record 24 of Set 3 | bluff
# City not found. Skipping...
# Processing record 25 of Set 3 | airai
# Processing record 26 of Set 3 | praia
# Processing record 27 of Set 3 | necochea
# Processing record 28 of Set 3 | alofi
# Processing record 29 of Set 3 | hofn
# Processing record 30 of Set 3 | coihaique
# City not found. Skipping...
# Processing record 31 of Set 3 | hanna
# Processing record 32 of Set 3 | husavik
# Processing record 33 of Set 3 | otofuke
# Processing record 34 of Set 3 | hauterive
# Processing record 35 of Set 3 | new norfolk
# City not found. Skipping...
# Processing record 36 of Set 3 | provideniya
# Processing record 37 of Set 3 | mount gambier
# Processing record 38 of Set 3 | tasiilaq
# Processing record 39 of Set 3 | ostrovnoy
# Processing record 40 of Set 3 | jumla
# Processing record 41 of Set 3 | kulhudhuffushi
# Processing record 42 of Set 3 | turka
# Processing record 43 of Set 3 | yerbogachen
# Processing record 44 of Set 3 | yarada
# Processing record 45 of Set 3 | tuatapere
# Processing record 46 of Set 3 | dangriga
# Processing record 47 of Set 3 | whitehorse
# Processing record 48 of Set 3 | oistins
# Processing record 49 of Set 3 | bairiki
# Processing record 50 of Set 3 | comodoro rivadavia
# Processing record 1 of Set 4 | wajid
# Processing record 2 of Set 4 | porbandar
# Processing record 3 of Set 4 | adelaide
# Processing record 4 of Set 4 | praia da vitoria
# Processing record 5 of Set 4 | mahebourg
# Processing record 6 of Set 4 | wuan
# Processing record 7 of Set 4 | grenfell
# Processing record 8 of Set 4 | mastic beach
# Processing record 9 of Set 4 | katsuura
# Processing record 10 of Set 4 | jardim
# Processing record 11 of Set 4 | port-gentil
# Processing record 12 of Set 4 | buraydah
# Processing record 13 of Set 4 | hami
# Processing record 14 of Set 4 | henties bay
# Processing record 15 of Set 4 | jinchang
# Processing record 16 of Set 4 | majene
# Processing record 17 of Set 4 | vao
# Processing record 18 of Set 4 | clyde river
# Processing record 19 of Set 4 | samarai
# Processing record 20 of Set 4 | pacific grove
# Processing record 21 of Set 4 | durusu
# City not found. Skipping...
# Processing record 22 of Set 4 | palmer
# Processing record 23 of Set 4 | uyskoye
# Processing record 24 of Set 4 | parintins
# Processing record 25 of Set 4 | kutum
# Processing record 26 of Set 4 | killorglin
# Processing record 27 of Set 4 | caravelas
# Processing record 28 of Set 4 | ballina
# Processing record 29 of Set 4 | santiago
# Processing record 30 of Set 4 | maceio
# Processing record 31 of Set 4 | carnarvon
# Processing record 32 of Set 4 | salamiyah
# Processing record 33 of Set 4 | bac lieu
# Processing record 34 of Set 4 | vaasa
# Processing record 35 of Set 4 | lufilufi
# Processing record 36 of Set 4 | lahij
# Processing record 37 of Set 4 | carutapera
# Processing record 38 of Set 4 | porosozero
# City not found. Skipping...
# Processing record 39 of Set 4 | barrow
# Processing record 40 of Set 4 | talnakh
# Processing record 41 of Set 4 | seymour
# Processing record 42 of Set 4 | port alfred
# Processing record 43 of Set 4 | kupang
# Processing record 44 of Set 4 | birjand
# Processing record 45 of Set 4 | boende
# Processing record 46 of Set 4 | araouane
# Processing record 47 of Set 4 | cabo san lucas
# Processing record 48 of Set 4 | haverhill
# Processing record 49 of Set 4 | san patricio
# Processing record 50 of Set 4 | bonfim
# Processing record 1 of Set 5 | micheweni
# Processing record 2 of Set 5 | olafsvik
# Processing record 3 of Set 5 | moundsville
# Processing record 4 of Set 5 | camrose
# Processing record 5 of Set 5 | padang
# Processing record 6 of Set 5 | nantucket
# Processing record 7 of Set 5 | tuktoyaktuk
# Processing record 8 of Set 5 | ahipara
# Processing record 9 of Set 5 | bambous virieux
# Processing record 10 of Set 5 | mogzon
# City not found. Skipping...
# Processing record 11 of Set 5 | lata
# Processing record 12 of Set 5 | havoysund
# Processing record 13 of Set 5 | grindavik
# Processing record 14 of Set 5 | mayskiy
# Processing record 15 of Set 5 | flinders
# Processing record 16 of Set 5 | mackay
# City not found. Skipping...
# Processing record 17 of Set 5 | kem
# Processing record 18 of Set 5 | port elizabeth
# Processing record 19 of Set 5 | harper
# Processing record 20 of Set 5 | dolores
# Processing record 21 of Set 5 | johi
# Processing record 22 of Set 5 | codrington
# Processing record 23 of Set 5 | atasu
# City not found. Skipping...
# Processing record 24 of Set 5 | sinnamary
# Processing record 25 of Set 5 | gardner
# Processing record 26 of Set 5 | dalnerechensk
# Processing record 27 of Set 5 | roald
# Processing record 28 of Set 5 | los llanos de aridane
# Processing record 29 of Set 5 | olavarria
# Processing record 30 of Set 5 | wattegama
# Processing record 31 of Set 5 | ribeira grande
# Processing record 32 of Set 5 | tulagi
# Processing record 33 of Set 5 | sur
# Processing record 34 of Set 5 | sukhumi
# Processing record 35 of Set 5 | chara
# Processing record 36 of Set 5 | klaksvik
# Processing record 37 of Set 5 | cayenne
# Processing record 38 of Set 5 | honningsvag
# Processing record 39 of Set 5 | half moon bay
# City not found. Skipping...
# Processing record 40 of Set 5 | acayucan
# City not found. Skipping...
# Processing record 41 of Set 5 | omboue
# Processing record 42 of Set 5 | komsomolskiy
# Processing record 43 of Set 5 | hualmay
# City not found. Skipping...
# Processing record 44 of Set 5 | port macquarie
# Processing record 45 of Set 5 | morgan city
# Processing record 46 of Set 5 | mocuba
# City not found. Skipping...
# Processing record 47 of Set 5 | puerto madero
# Processing record 48 of Set 5 | garissa
# Processing record 49 of Set 5 | grafton
# Processing record 50 of Set 5 | hamilton
# City not found. Skipping...
# Processing record 1 of Set 6 | giaveno
# Processing record 2 of Set 6 | catuday
# Processing record 3 of Set 6 | duekoue
# Processing record 4 of Set 6 | marawi
# Processing record 5 of Set 6 | saskylakh
# Processing record 6 of Set 6 | alvinopolis
# Processing record 7 of Set 6 | mirandola
# Processing record 8 of Set 6 | kiama
# Processing record 9 of Set 6 | fort nelson
# Processing record 10 of Set 6 | oranjestad
# Processing record 11 of Set 6 | katherine
# Processing record 12 of Set 6 | japura
# Processing record 13 of Set 6 | milledgeville
# Processing record 14 of Set 6 | honiara
# Processing record 15 of Set 6 | umm kaddadah
# Processing record 16 of Set 6 | tall kayf
# Processing record 17 of Set 6 | aloleng
# Processing record 18 of Set 6 | sovetskaya gavan
# Processing record 19 of Set 6 | neuchatel
# Processing record 20 of Set 6 | alekseyevsk
# Processing record 21 of Set 6 | havre-saint-pierre
# Processing record 22 of Set 6 | souillac
# Processing record 23 of Set 6 | floro
# Processing record 24 of Set 6 | brunsbuttel
# Processing record 25 of Set 6 | plettenberg bay
# Processing record 26 of Set 6 | thouars
# Processing record 27 of Set 6 | labuhan
# Processing record 28 of Set 6 | vila velha
# Processing record 29 of Set 6 | pacifica
# Processing record 30 of Set 6 | san carlos de bariloche
# Processing record 31 of Set 6 | vostok
# Processing record 32 of Set 6 | pervomayskoye
# Processing record 33 of Set 6 | vallenar
# Processing record 34 of Set 6 | shatsk
# Processing record 35 of Set 6 | sambava
# Processing record 36 of Set 6 | acarau
# City not found. Skipping...
# Processing record 37 of Set 6 | vila franca do campo
# Processing record 38 of Set 6 | namatanai
# City not found. Skipping...
# Processing record 39 of Set 6 | qujing
# Processing record 40 of Set 6 | teknaf
# Processing record 41 of Set 6 | dunedin
# Processing record 42 of Set 6 | kadambur
# City not found. Skipping...
# Processing record 43 of Set 6 | torbay
# Processing record 44 of Set 6 | roseburg
# Processing record 45 of Set 6 | san-pedro
# Processing record 46 of Set 6 | faanui
# Processing record 47 of Set 6 | esperance
# Processing record 48 of Set 6 | saint-francois
# Processing record 49 of Set 6 | urengoy
# Processing record 50 of Set 6 | mackenzie
# Processing record 1 of Set 7 | fukue
# Processing record 2 of Set 7 | narsaq
# Processing record 3 of Set 7 | tiksi
# Processing record 4 of Set 7 | hithadhoo
# Processing record 5 of Set 7 | maua
# Processing record 6 of Set 7 | bereda
# Processing record 7 of Set 7 | naze
# City not found. Skipping...
# Processing record 8 of Set 7 | college
# Processing record 9 of Set 7 | eureka
# Processing record 10 of Set 7 | tyret pervaya
# Processing record 11 of Set 7 | serabu
# Processing record 12 of Set 7 | namwala
# Processing record 13 of Set 7 | eskisehir
# Processing record 14 of Set 7 | srednekolymsk
# Processing record 15 of Set 7 | shimoda
# Processing record 16 of Set 7 | lamovita
# Processing record 17 of Set 7 | sao paulo de olivenca
# Processing record 18 of Set 7 | ugoofaaru
# City not found. Skipping...
# Processing record 19 of Set 7 | cumra
# Processing record 20 of Set 7 | hovd
# Processing record 21 of Set 7 | masallatah
# Processing record 22 of Set 7 | kieta
# Processing record 23 of Set 7 | banda aceh
# Processing record 24 of Set 7 | bara
# Processing record 25 of Set 7 | pangnirtung
# Processing record 26 of Set 7 | mwense
# Processing record 27 of Set 7 | portales
# City not found. Skipping...
# Processing record 28 of Set 7 | cherskiy
# City not found. Skipping...
# City not found. Skipping...
# Processing record 29 of Set 7 | khatanga
# Processing record 30 of Set 7 | ciudad bolivar
# Processing record 31 of Set 7 | portland
# Processing record 32 of Set 7 | reconquista
# Processing record 33 of Set 7 | meulaboh
# Processing record 34 of Set 7 | thinadhoo
# Processing record 35 of Set 7 | doka
# Processing record 36 of Set 7 | kalianget
# Processing record 37 of Set 7 | bukachacha
# City not found. Skipping...
# Processing record 38 of Set 7 | tautira
# Processing record 39 of Set 7 | hambantota
# Processing record 40 of Set 7 | arraial do cabo
# City not found. Skipping...
# Processing record 41 of Set 7 | stornoway
# Processing record 42 of Set 7 | touros
# City not found. Skipping...
# Processing record 43 of Set 7 | aswan
# Processing record 44 of Set 7 | lumsden
# Processing record 45 of Set 7 | upernavik
# Processing record 46 of Set 7 | sao jose da coroa grande
# Processing record 47 of Set 7 | darhan
# Processing record 48 of Set 7 | kizema
# Processing record 49 of Set 7 | jesus del monte
# Processing record 50 of Set 7 | xichang
# Processing record 1 of Set 8 | trinidad
# Processing record 2 of Set 8 | acapulco
# Processing record 3 of Set 8 | puerto escondido
# Processing record 4 of Set 8 | saint-joseph
# Processing record 5 of Set 8 | alamos
# Processing record 6 of Set 8 | kousseri
# Processing record 7 of Set 8 | praya
# Processing record 8 of Set 8 | kaiu
# Processing record 9 of Set 8 | la seyne-sur-mer
# Processing record 10 of Set 8 | berlevag
# City not found. Skipping...
# Processing record 11 of Set 8 | kapuskasing
# City not found. Skipping...
# Processing record 12 of Set 8 | daru
# Processing record 13 of Set 8 | bathsheba
# Processing record 14 of Set 8 | piopio
# Processing record 15 of Set 8 | valladolid
# Processing record 16 of Set 8 | upata
# Processing record 17 of Set 8 | paragominas
# Processing record 18 of Set 8 | mahon
# Processing record 19 of Set 8 | magugu
# Processing record 20 of Set 8 | torzhok
# Processing record 21 of Set 8 | masuguru
# Processing record 22 of Set 8 | wukari
# Processing record 23 of Set 8 | bukama
# Processing record 24 of Set 8 | cananeia
# Processing record 25 of Set 8 | ajdabiya
# Processing record 26 of Set 8 | chiang rai
# Processing record 27 of Set 8 | avarua
# Processing record 28 of Set 8 | manokwari
# Processing record 29 of Set 8 | palora
# Processing record 30 of Set 8 | aasiaat
# Processing record 31 of Set 8 | nouadhibou
# Processing record 32 of Set 8 | pangai
# Processing record 33 of Set 8 | zlobin
# Processing record 34 of Set 8 | umea
# Processing record 35 of Set 8 | murdochville
# Processing record 36 of Set 8 | pontianak
# Processing record 37 of Set 8 | vawkavysk
# Processing record 38 of Set 8 | saint-pierre
# City not found. Skipping...
# Processing record 39 of Set 8 | namibe
# Processing record 40 of Set 8 | fairbanks
# Processing record 41 of Set 8 | cabra
# Processing record 42 of Set 8 | gopalpur
# Processing record 43 of Set 8 | siuna
# Processing record 44 of Set 8 | cockburn town
# Processing record 45 of Set 8 | gunnedah
# Processing record 46 of Set 8 | pingxiang
# Processing record 47 of Set 8 | masvingo
# Processing record 48 of Set 8 | aconibe
# Processing record 49 of Set 8 | sibolga
# Processing record 50 of Set 8 | druzhba
# Processing record 1 of Set 9 | mujiayingzi
# Processing record 2 of Set 9 | howard springs
# Processing record 3 of Set 9 | bayog
# Processing record 4 of Set 9 | waingapu
# Processing record 5 of Set 9 | mamou
# Processing record 6 of Set 9 | lebanon
# Processing record 7 of Set 9 | ambilobe
# Processing record 8 of Set 9 | angoche
# Processing record 9 of Set 9 | karaton
# Processing record 10 of Set 9 | hudiksvall
# Processing record 11 of Set 9 | jiuquan
# Processing record 12 of Set 9 | tura
# Processing record 13 of Set 9 | saldanha
# Processing record 14 of Set 9 | hasaki
# Processing record 15 of Set 9 | egvekinot
# Processing record 16 of Set 9 | san quintin
# Processing record 17 of Set 9 | lake charles
# Processing record 18 of Set 9 | ormara
# Processing record 19 of Set 9 | nyurba
# Processing record 20 of Set 9 | leningradskiy
# Processing record 21 of Set 9 | priiskovyy
# Processing record 22 of Set 9 | mingguang
# Processing record 23 of Set 9 | jati
# Processing record 24 of Set 9 | ingham
# Processing record 25 of Set 9 | dingle
# Processing record 26 of Set 9 | choix
# Processing record 27 of Set 9 | port hedland
# Processing record 28 of Set 9 | vilhena
# Processing record 29 of Set 9 | aketi
# Processing record 30 of Set 9 | arman
# Processing record 31 of Set 9 | zaysan
# Processing record 32 of Set 9 | vestmannaeyjar
# Processing record 33 of Set 9 | santa maria
# Processing record 34 of Set 9 | alice springs
# Processing record 35 of Set 9 | manaure
# Processing record 36 of Set 9 | kamaishi
# Processing record 37 of Set 9 | kuryk
# Processing record 38 of Set 9 | prince rupert
# Processing record 39 of Set 9 | erdenet
# Processing record 40 of Set 9 | santa ines
# Processing record 41 of Set 9 | surat
# Processing record 42 of Set 9 | anadyr
# Processing record 43 of Set 9 | ingraj bazar
# Processing record 44 of Set 9 | korla
# Processing record 45 of Set 9 | sakakah
# Processing record 46 of Set 9 | birao
# Processing record 47 of Set 9 | taoudenni
# Processing record 48 of Set 9 | yukamenskoye
# Processing record 49 of Set 9 | shestakovo
# City not found. Skipping...
# Processing record 50 of Set 9 | singaraja
# Processing record 1 of Set 10 | zhigansk
# Processing record 2 of Set 10 | killarney
# Processing record 3 of Set 10 | petropavlovsk-kamchatskiy
# Processing record 4 of Set 10 | kazerun
# Processing record 5 of Set 10 | te anau
# City not found. Skipping...
# Processing record 6 of Set 10 | orje
# Processing record 7 of Set 10 | awjilah
# Processing record 8 of Set 10 | palmeiras de goias
# Processing record 9 of Set 10 | bulgan
# Processing record 10 of Set 10 | sorland
# Processing record 11 of Set 10 | morant bay
# Processing record 12 of Set 10 | zilair
# Processing record 13 of Set 10 | westport
# Processing record 14 of Set 10 | cairns
# Processing record 15 of Set 10 | ayan
# Processing record 16 of Set 10 | acajutla
# Processing record 17 of Set 10 | osinovo
# Processing record 18 of Set 10 | bengkulu
# Processing record 19 of Set 10 | akyab
# Processing record 20 of Set 10 | mtwara
# Processing record 21 of Set 10 | mae hong son
# Processing record 22 of Set 10 | eyl
# Processing record 23 of Set 10 | mirnyy
# Processing record 24 of Set 10 | kruisfontein
# Processing record 25 of Set 10 | paamiut
# Processing record 26 of Set 10 | zinder
# Processing record 27 of Set 10 | san juan
# Processing record 28 of Set 10 | todos santos
# Processing record 29 of Set 10 | bela vista
# Processing record 30 of Set 10 | matranovak
# Processing record 31 of Set 10 | kasempa
# Processing record 32 of Set 10 | rio cuarto
# Processing record 33 of Set 10 | elesbao veloso
# Processing record 34 of Set 10 | port blair
# Processing record 35 of Set 10 | qaqortoq
# Processing record 36 of Set 10 | wewak
# Processing record 37 of Set 10 | omsukchan
# Processing record 38 of Set 10 | sherpur
# City not found. Skipping...
# Processing record 39 of Set 10 | ulaanbaatar
# Processing record 40 of Set 10 | khunti
# Processing record 41 of Set 10 | davila
# City not found. Skipping...
# Processing record 42 of Set 10 | nadym
# City not found. Skipping...
# Processing record 43 of Set 10 | kavaratti
# City not found. Skipping...
# Processing record 44 of Set 10 | vostochnyy
# Processing record 45 of Set 10 | ati
# Processing record 46 of Set 10 | makubetsu
# Processing record 47 of Set 10 | tignere
# Processing record 48 of Set 10 | jinka
# Processing record 49 of Set 10 | diapaga
# Processing record 50 of Set 10 | pisco
# Processing record 1 of Set 11 | beatrice
# Processing record 2 of Set 11 | talalayivka
# Processing record 3 of Set 11 | fairfield
# Processing record 4 of Set 11 | benalla
# Processing record 5 of Set 11 | brody
# Processing record 6 of Set 11 | cocobeach
# Processing record 7 of Set 11 | yingkou
# Processing record 8 of Set 11 | roma
# Processing record 9 of Set 11 | malpe
# City not found. Skipping...
# Processing record 10 of Set 11 | tanete
# Processing record 11 of Set 11 | shelburne
# Processing record 12 of Set 11 | arlit
# Processing record 13 of Set 11 | santa rosa
# Processing record 14 of Set 11 | poum
# Processing record 15 of Set 11 | siirt
# Processing record 16 of Set 11 | broken hill
# Processing record 17 of Set 11 | otavi
# Processing record 18 of Set 11 | kandrian
# Processing record 19 of Set 11 | sumbe
# Processing record 20 of Set 11 | tsumeb
# Processing record 21 of Set 11 | storebo
# Processing record 22 of Set 11 | gunjur
# Processing record 23 of Set 11 | petropavlovka
# Processing record 24 of Set 11 | zonguldak
# Processing record 25 of Set 11 | itacarambi
# Processing record 26 of Set 11 | bandarbeyla
# Processing record 27 of Set 11 | mincivan
# Processing record 28 of Set 11 | ambulu
# Processing record 29 of Set 11 | ucluelet
# Processing record 30 of Set 11 | bud
# Processing record 31 of Set 11 | capoterra
# Processing record 32 of Set 11 | beyneu
# Processing record 33 of Set 11 | amurrio
# City not found. Skipping...
# Processing record 34 of Set 11 | mecca
# Processing record 35 of Set 11 | port hardy
# Processing record 36 of Set 11 | balila
# Processing record 37 of Set 11 | mao
# Processing record 38 of Set 11 | byron bay
# Processing record 39 of Set 11 | mount isa
# Processing record 40 of Set 11 | ilulissat
# Processing record 41 of Set 11 | russell
# Processing record 42 of Set 11 | marsa matruh
# City not found. Skipping...
# Processing record 43 of Set 11 | gamba
# Processing record 44 of Set 11 | san cristobal
# City not found. Skipping...
# Processing record 45 of Set 11 | soubre
# Processing record 46 of Set 11 | jega
# Processing record 47 of Set 11 | kyra
# Processing record 48 of Set 11 | novobureyskiy
# Processing record 49 of Set 11 | karratha
# Processing record 50 of Set 11 | waupun
# Processing record 1 of Set 12 | nova olinda do norte
# Processing record 2 of Set 12 | vagur
# Processing record 3 of Set 12 | el alto
# City not found. Skipping...
# Processing record 4 of Set 12 | mapimi
# Processing record 5 of Set 12 | darnah
# Processing record 6 of Set 12 | moose factory
# City not found. Skipping...
# Processing record 7 of Set 12 | gorontalo
# Processing record 8 of Set 12 | paracatu
# Processing record 9 of Set 12 | gbadolite
# Processing record 10 of Set 12 | severnyy
# Processing record 11 of Set 12 | nicoya
# Processing record 12 of Set 12 | rosarito
# Processing record 13 of Set 12 | bukoba
# Processing record 14 of Set 12 | gillette
# City not found. Skipping...
# Processing record 15 of Set 12 | nemuro
# Processing record 16 of Set 12 | jackson
# Processing record 17 of Set 12 | den helder
# Processing record 18 of Set 12 | manta
# Processing record 19 of Set 12 | fort abbas
# Processing record 20 of Set 12 | pangody
# Processing record 21 of Set 12 | mundo nuevo
# Processing record 22 of Set 12 | wanlaweyn
# Processing record 23 of Set 12 | san isidro
# Processing record 24 of Set 12 | ancud
# Processing record 25 of Set 12 | tilichiki
# Processing record 26 of Set 12 | aleksandrovsk-sakhalinskiy
# Processing record 27 of Set 12 | malindi
# Processing record 28 of Set 12 | aljezur
# Processing record 29 of Set 12 | svetlaya
# Processing record 30 of Set 12 | usinsk
# Processing record 31 of Set 12 | biak
# Processing record 32 of Set 12 | erenhot
# Processing record 33 of Set 12 | kholm
# Processing record 34 of Set 12 | luoyang
# Processing record 35 of Set 12 | marzuq
# Processing record 36 of Set 12 | verona
# Processing record 37 of Set 12 | gaozhou
# Processing record 38 of Set 12 | ibate
# Processing record 39 of Set 12 | ossora
# Processing record 40 of Set 12 | muravlenko
# Processing record 41 of Set 12 | udachnyy
# Processing record 42 of Set 12 | kabalo
# Processing record 43 of Set 12 | batagay-alyta
# Processing record 44 of Set 12 | aksha
# Processing record 45 of Set 12 | moroni
# Processing record 46 of Set 12 | nampula
# Processing record 47 of Set 12 | xicotencatl
# Processing record 48 of Set 12 | wagar
# Processing record 49 of Set 12 | meyzieu
# Processing record 50 of Set 12 | kayes
# Processing record 1 of Set 13 | kovylkino
# Processing record 2 of Set 13 | ozernovskiy
# City not found. Skipping...
# Processing record 3 of Set 13 | saint pete beach
# Processing record 4 of Set 13 | kalanwali
# Processing record 5 of Set 13 | muros
# Processing record 6 of Set 13 | witbank
# Processing record 7 of Set 13 | amahai
# Processing record 8 of Set 13 | salinas
# Processing record 9 of Set 13 | simao
# Processing record 10 of Set 13 | poyarkovo
# Processing record 11 of Set 13 | pochutla
# -------------------------------
# Data Retrieval Complete
# -------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#create dataframe of weather statistics of recorded cities
weather_data = pd.DataFrame({
    "City": city_name, "Lat": lat, "Lng": lng,
    "Max Temp": max_temp, "Humidity": humidity,
    "Cloudiness": cloudiness, "Wind Speed": wind_speed,
    "Country": country, "Date": date
})

#save to output
weather_data.to_csv("Output/weather_data.csv", index=False)

#output
weather_data.head()
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      Rikitea -23.1203 -134.9692     25.63        72         100        3.12
# 1  Yellowknife  62.4560 -114.3525    -13.00        52          20        6.17
# 2       Aykhal  66.0000  111.5000    -10.54        89          99        6.39
# 3      Mulchén -37.7167  -72.2333     10.54        70           3        1.62
# 4      Winston  28.0317  -82.0148     24.00        60           1        2.57
#
#   Country        Date
# 0      PF  1619487006
# 1      CA  1619486807
# 2      RU  1619487006
# 3      CL  1619487006
# 4      US  1619487006

# %%
#descriptive statistics of weather data
weather_descriptive_stats = weather_data.describe()
weather_descriptive_stats.to_csv("Output/weather_descriptive_stats.csv", index=False)

#output
weather_descriptive_stats
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  611.000000  611.000000  611.000000  611.000000  611.000000  611.000000
# mean    20.242603   17.321509   16.196841   68.716858   51.919804    3.405155
# std     32.434248   88.874766   10.571795   22.934333   39.442364    2.333631
# min    -54.800000 -179.166700  -13.000000    4.000000    0.000000    0.180000
# 25%     -5.075000  -60.047900    8.330000   56.500000   10.000000    1.540000
# 50%     23.016700   21.286900   17.220000   73.000000   53.000000    2.760000
# 75%     46.727800   98.648300   25.420000   87.000000   91.500000    4.630000
# max     78.218600  178.416700   34.060000  100.000000  100.000000   11.830000
#
#                Date
# count  6.110000e+02
# mean   1.619487e+09
# std    5.067332e+01
# min    1.619487e+09
# 25%    1.619487e+09
# 50%    1.619487e+09
# 75%    1.619487e+09
# max    1.619487e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
weather_data["Humidity"].max()
# Out:
# 100

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
#define x and y variables
latitude = weather_data["Lat"]
temperature = weather_data["Max Temp"]

#plot and label
plt.scatter(latitude, temperature, marker="o", facecolors="b", edgecolors="black", alpha=0.8)
plt.xlabel("Latitude")
plt.ylabel("Max Temperature(C)")
plt.title("City Latitude vs Max Temperature")
plt.grid()

#save to output
plt.savefig("Output/Latitude_Max_Temp.png")

#output
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
#define x and y variable
humidity = weather_data["Humidity"]

#plot and label
plt.scatter(latitude, humidity, marker="o", facecolors="b", edgecolors="black", alpha=0.8)
plt.xlabel("Latitude")
plt.ylabel("Humidity(%)")
plt.title("City Latitude vs Humidity")
plt.grid()

#save to output
plt.savefig("Output/Latitude_Humidity.png")

#output
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# define x and y variable
cloudiness = weather_data["Cloudiness"]

#plot and label
plt.scatter(latitude, cloudiness, marker="o", facecolors="b", edgecolors="black", alpha=0.8)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness(%)")
plt.title("City Latitude vs Cloudiness")
plt.grid()

#save to output
plt.savefig("Output/Latitude_Cloudiness.png")

#output
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# define x and y variable
wind = weather_data["Wind Speed"]

#plot and label
plt.scatter(latitude, wind, marker="o", facecolors="b", edgecolors="black", alpha=0.8)
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (Mph)")
plt.title("City Latitude vs Wind Speed")
plt.grid()

#save to output
plt.savefig("Output/Latitude_Wind_Speed.png")

#output
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
#subsetting weather data into northern and southern hemisphere
north_data = weather_data.loc[weather_data["Lat"] >= 0, :]
south_data = weather_data.loc[weather_data["Lat"] <= 0, :]

#defining x variables for all scatterplots for regression
north_lat = north_data["Lat"]
south_lat = south_data["Lat"]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#defining y variable
north_temp = north_data["Max Temp"]

# Calculate the correlation coefficient 
correlation = st.pearsonr(north_lat, north_temp)
#output to show relationship between mouse weight and average tumour volum (mm3)
print(f"The r-value is : {correlation[0]}.")

#linear regressions model
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(north_lat, north_temp)
regress_values = north_lat * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_eq,(0,-10),fontsize=15,color="red")
plt.plot(north_lat,regress_values,"r-")

#scatter plot and labeling
plt.scatter(north_lat, north_temp, marker="o", facecolors="b", edgecolors="black", alpha=0.75)
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.title("Latitudes in Northern Hemisphere Vs Max Temperature(C)")

#save to output
plt.savefig("Output/North_Latitude_Max_Temp_Regression.png")

#output
plt.show()
# Out:
# The r-value is : -0.8974524362088443.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#defining y variable
south_temp = south_data["Max Temp"]

# Calculate the correlation coefficient 
correlation = st.pearsonr(south_lat, south_temp)
#output to show relationship between mouse weight and average tumour volum (mm3)
print(f"The r-value is : {correlation[0]}.")

#linear regressions model
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(south_lat, south_temp)
regress_values = south_lat * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_eq,(-55, 30),fontsize=15,color="red")
plt.plot(south_lat,regress_values,"r-")

#scatter plot and labeling
plt.scatter(south_lat, south_temp, marker="o", facecolors="b", edgecolors="black", alpha=0.75)
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.title("Latitudes in Southern Hemisphere Vs Max Temperature(C)")

#save to output
plt.savefig("Output/South_Latitude_Max_Temp_Regression.png")

#output
plt.show()
# Out:
# The r-value is : 0.7464011153905428.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#defining y variable
north_humidity = north_data["Humidity"]

# Calculate the correlation coefficient 
correlation = st.pearsonr(north_lat, north_humidity)
#output to show relationship between mouse weight and average tumour volum (mm3)
print(f"The r-value is : {correlation[0]}.")

#linear regressions model
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(north_lat, north_humidity)
regress_values = north_lat * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_eq,(45,10),fontsize=15,color="red")
plt.plot(north_lat,regress_values,"r-")

#scatter plot and labeling
plt.scatter(north_lat, north_humidity, marker="o", facecolors="b", edgecolors="black", alpha=0.75)
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("Latitudes in Northern Hemisphere Vs Humidity")

#save to output
plt.savefig("Output/North_Latitude_Humidity_Regression.png")

#output
plt.show()
# Out:
# The r-value is : 0.122129360254009.

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#defining y variable
south_humidity = south_data["Humidity"]

# Calculate the correlation coefficient 
correlation = st.pearsonr(south_lat, south_humidity)
#output to show relationship between mouse weight and average tumour volum (mm3)
print(f"The r-value is : {correlation[0]}.")

#linear regressions model
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(south_lat, south_humidity)
regress_values = south_lat * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_eq,(-55,20),fontsize=15,color="red")
plt.plot(south_lat,regress_values,"r-")

#scatter plot and labeling
plt.scatter(south_lat, south_humidity, marker="o", facecolors="b", edgecolors="black", alpha=0.75)
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("Latitudes in Southern Hemisphere Vs Humidity")

#save to output
plt.savefig("Output/South_Latitude_Humidity_Regression.png")

#output
plt.show()
# Out:
# The r-value is : 0.18981787214195164.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#defining y variable
north_cloudiness = north_data["Cloudiness"]

# Calculate the correlation coefficient 
correlation = st.pearsonr(north_lat, north_cloudiness)
#output to show relationship between mouse weight and average tumour volum (mm3)
print(f"The r-value is : {correlation[0]}.")

#linear regressions model
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(north_lat, north_cloudiness)
regress_values = north_lat * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_eq,(45,30),fontsize=15,color="red")
plt.plot(north_lat,regress_values,"r-")

#scatter plot and labeling
plt.scatter(north_lat, north_cloudiness, marker="o", facecolors="b", edgecolors="black", alpha=0.75)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("Latitudes in Northern Hemisphere Vs Cloudiness")

#save to output
plt.savefig("Output/North_Latitude_Cloudiness_Regression.png")

#output
plt.show()
# Out:
# The r-value is : 0.11756009095699026.

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#defining y variable
south_cloudiness = south_data["Cloudiness"]

# Calculate the correlation coefficient 
correlation = st.pearsonr(south_lat, south_cloudiness)
#output to show relationship between mouse weight and average tumour volum (mm3)
print(f"The r-value is : {correlation[0]}.")

#linear regressions model
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(south_lat, south_cloudiness)
regress_values = south_lat * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_eq,(-55,20),fontsize=15,color="red")
plt.plot(south_lat,regress_values,"r-")

#scatter plot and labeling
plt.scatter(south_lat, south_cloudiness, marker="o", facecolors="b", edgecolors="black", alpha=0.75)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("Latitudes in Southern Hemisphere Vs Cloudiness")

#save to output
plt.savefig("Output/South_Latitude_Cloudiness_Regression.png")

#output
plt.show()
# Out:
# The r-value is : 0.20170492498599948.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#defining y variable
north_wind = north_data["Wind Speed"]

# Calculate the correlation coefficient 
correlation = st.pearsonr(north_lat, north_wind)
#output to show relationship between mouse weight and average tumour volum (mm3)
print(f"The r-value is : {correlation[0]}.")

#linear regressions model
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(north_lat, north_wind)
regress_values = north_lat * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_eq,(45,10),fontsize=15,color="red")
plt.plot(north_lat,regress_values,"r-")

#scatter plot and labeling
plt.scatter(north_lat, north_wind, marker="o", facecolors="b", edgecolors="black", alpha=0.75)
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title("Latitudes in Northern Hemisphere Vs Wind Speed")

#save to output
plt.savefig("Output/North_Latitude_Wind_Speed_Regression.png")

#output
plt.show()
# Out:
# The r-value is : 0.22690412658681558.

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#defining y variable
south_wind = south_data["Wind Speed"]

# Calculate the correlation coefficient 
correlation = st.pearsonr(south_lat, south_wind)
#output to show relationship between mouse weight and average tumour volum (mm3)
print(f"The r-value is : {correlation[0]}.")

#linear regressions model
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(south_lat, south_wind)
regress_values = south_lat * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_eq,(-55,10),fontsize=15,color="red")
plt.plot(south_lat,regress_values,"r-")

#scatter plot and labeling
plt.scatter(south_lat, south_wind, marker="o", facecolors="b", edgecolors="black", alpha=0.75)
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title("Latitudes in Southern Hemisphere Vs Wind Speed")

#save to output
plt.savefig("Output/South_Latitude_Wind_Speed_Regression.png")

#output
plt.show()
# Out:
# The r-value is : -0.14284161159662762.
